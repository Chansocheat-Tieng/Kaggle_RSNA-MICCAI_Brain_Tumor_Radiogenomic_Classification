# %% [markdown]
# Thanks to :
#
#     https://www.kaggle.com/arnabs007/part-1-rsna-miccai-btrc-understanding-the-data
#     https://www.kaggle.com/rluethy/efficientnet3d-with-one-mri-type
#     https://www.kaggle.com/ammarnassanalhajali/brain-tumor-3d-training
#     https://www.kaggle.com/ammarnassanalhajali/brain-tumor-3d-inference
#     https://keras.io/examples/vision/3D_image_classification/

# %%
import os 
import glob
import re
import math
import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt
import seaborn as sns
import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut

from random import shuffle
from sklearn import model_selection as sk_model_selection

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.metrics import AUC

# %%
# try:
#     # Disable all GPUS
#     tf.config.set_visible_devices([], 'GPU')
#     visible_devices = tf.config.get_visible_devices()
#     for device in visible_devices:
#         assert device.device_type != 'GPU'
# except:
#     # Invalid device or cannot modify virtual devices once initialized.
#     pass


# # tf.test.gpu_device_name()

# %%
## Enable this to run on PC

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], enable=True)
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Loading Data

# %%
# data_directory = '../input/rsna-miccai-brain-tumor-radiogenomic-classification'
# pytorch3dpath = "../input/efficientnetpyttorch3d/EfficientNet-PyTorch-3D"

data_directory = ''
mri_types_orig = ['FLAIR','T1w','T1wCE','T2w']
mri_types = ['FLAIR', 'T2w']

IMAGE_SIZE = 128
NUM_IMAGES_PER_TYPE = 32
NUM_IMAGES = NUM_IMAGES_PER_TYPE * len(mri_types)
BATCH_SIZE= 4

train_df = pd.read_csv("train_labels.csv")

to_exclude = [109, 123, 709]
train_df = train_df[~train_df['BraTS21ID'].isin(to_exclude)]

train_df['BraTS21ID5'] = [format(x, '05d') for x in train_df.BraTS21ID]
print(len(train_df))
train_df
# Out:
# 582
#      BraTS21ID  MGMT_value BraTS21ID5
# 0            0           1      00000
# 1            2           1      00002
# 2            3           0      00003
# 3            5           1      00005
# 4            6           1      00006
# ..         ...         ...        ...
# 580       1005           1      01005
# 581       1007           1      01007
# 582       1008           1      01008
# 583       1009           0      01009
# 584       1010           0      01010
#
# [582 rows x 3 columns]

# %%
sample_submission = pd.read_csv('sample_submission.csv')
test=sample_submission
test['BraTS21ID5'] = [format(x, '05d') for x in test.BraTS21ID]
test.head(3)
# Out:
#    BraTS21ID  MGMT_value BraTS21ID5
# 0          1         0.5      00001
# 1         13         0.5      00013
# 2         15         0.5      00015

# %% [markdown]
# # Functions to load images

# %%
def load_dicom_image(path, img_size=IMAGE_SIZE, voi_lut=True, rotate=0):
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    if voi_lut:
        data = apply_voi_lut(dicom.pixel_array, dicom)
    else:
        data = dicom.pixel_array
        
    if rotate > 0:
        rot_choices = [0, cv2.ROTATE_90_CLOCKWISE, cv2.ROTATE_90_COUNTERCLOCKWISE, cv2.ROTATE_180]
        data = cv2.rotate(data, rot_choices[rotate])
        
    data = cv2.resize(data, (img_size, img_size))
    return data


def load_dicom_images_3d(scan_id, split = 'train', mri_type="FLAIR", num_imgs=NUM_IMAGES_PER_TYPE, img_size=IMAGE_SIZE, rotate=0):

    files = sorted(glob.glob(f"{split}/{scan_id}/{mri_type}/*.dcm"), 
               key=lambda var:[int(x) if x.isdigit() else x for x in re.findall(r'[^0-9]|[0-9]+', var)])

    # middle = len(files)//2
    # num_imgs2 = num_imgs
    # p1 = max(0, middle - num_imgs2)
    # p2 = min(len(files), middle + num_imgs2)
    # img3d = np.stack([load_dicom_image(f, rotate=rotate) for f in files[p1:p2:2]]).T 

    middle = len(files)//2
    num_imgs2 = num_imgs//2
    p1 = max(0, middle - num_imgs2)
    p2 = min(len(files), middle + num_imgs2)
    img3d = np.stack([load_dicom_image(f, rotate=rotate) for f in files[p1:p2]]).T 
    
    # if img3d.shape[-1] < 3*num_imgs//4:
    #     middle = len(files)//2
    #     num_imgs2 = num_imgs//2
    #     p1 = max(0, middle - num_imgs2)
    #     p2 = min(len(files), middle + num_imgs2)
    #     img3d = np.stack([load_dicom_image(f, rotate=rotate) for f in files[p1:p2]]).T 

    if img3d.shape[-1] < num_imgs:
        # n_zero = np.zeros((img_size, img_size, num_imgs - img3d.shape[-1]))
        n_zero_front = np.zeros((img_size, img_size, (num_imgs - img3d.shape[-1])//2))
        n_zero_back = np.zeros((img_size, img_size, num_imgs - img3d.shape[-1] - n_zero_front.shape[-1]))

        # img3d = np.concatenate((img3d, n_zero), axis = -1)
        img3d = np.concatenate((n_zero_front, img3d, n_zero_back), axis = -1)

        
    if np.min(img3d) < np.max(img3d):
        img3d = img3d - np.min(img3d)
        img3d = img3d / np.max(img3d)
            
    return np.expand_dims(img3d,0)

def load_dicom_images_3d_all(scan_id, split = 'train'):
    img3d_all = np.concatenate([load_dicom_images_3d(scan_id, split, mri_type) for mri_type in mri_types], axis = -1)
    
    return img3d_all

a = load_dicom_images_3d_all("00001", 'test')
print(a.shape)
print(np.min(a), np.max(a), np.mean(a), np.median(a))
# Out:
# (1, 128, 128, 32)
# 0.0 1.0 0.06559258996604549 0.0001678745068163368

# %% [markdown]
# # Splitting Data

# %%
df_train, df_valid = sk_model_selection.train_test_split(
    train_df, 
    test_size=0.2, 
    random_state=12, 
    stratify=train_df["MGMT_value"],
    shuffle=True,
)

# %%
del train_df
df_train
# Out:
#      BraTS21ID  MGMT_value BraTS21ID5
# 278        405           0      00405
# 446        645           0      00645
# 511        746           1      00746
# 46          71           1      00071
# 269        392           0      00392
# ..         ...         ...        ...
# 106        158           0      00158
# 199        294           1      00294
# 116        172           0      00172
# 468        682           0      00682
# 82         124           0      00124
#
# [465 rows x 3 columns]

# %% [markdown]
# #  Custom Data Generator

# %%
from tensorflow.keras.utils import Sequence

class Dataset(Sequence):
    def __init__(self,df,split = 'train', is_train=True,batch_size=BATCH_SIZE,shuffle=True):
        self.idx = df["BraTS21ID"].values
        self.paths = df["BraTS21ID5"].values
        self.y =  df["MGMT_value"].values
        self.is_train = is_train
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.split = split
        
    def __len__(self):
        return math.ceil(len(self.idx)/self.batch_size)
   
    def __getitem__(self,ids):
        id_path= self.paths[ids]
        batch_paths = self.paths[ids * self.batch_size:(ids + 1) * self.batch_size]
        split=self.split
        
        if self.y is not None:
            batch_y = self.y[ids * self.batch_size: (ids + 1) * self.batch_size]
            
        if split == 'train':
            list_x =  [load_dicom_images_3d_all(x, split) for x in batch_paths]
            batch_X = np.stack(list_x, axis=4)
        else:
            list_x =  load_dicom_images_3d_all(id_path, split)
            batch_X = np.stack(list_x)
            
        if self.is_train:
            return batch_X, batch_y
        else:
            return batch_X

# %%
train_dataset = Dataset(df_train, 'train')
valid_dataset = Dataset(df_valid, 'train')
test_dataset = Dataset(test, 'test', is_train=False)

# print(len(train_dataset))
# print([type(a) for a in train_dataset[0]])
# print([a.shape for a in train_dataset[0]])
# print(train_dataset[0][0][0][0][0][0])
# print(len(test_dataset))

# %%
def plot_sample_all(images, label, j): 
    plt.figure(figsize=(35, 35))
    for i in range(NUM_IMAGES):
        # plt.subplot(14,14,(i+1))
        plt.subplot(16,16,(i+1))
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[0,:,:,i,j], cmap="gray")
    plt.show()

# %%
i = 0
j = 0
images, label = train_dataset[i]
plot_sample_all(images, label, j)

# %%
i = 0
j = 1
images, label = train_dataset[i]
plot_sample_all(images, label, j)

# %%
i = 0
j = 2
images, label = train_dataset[i]
plot_sample_all(images, label, j)

# %%
i = 0
j = 3
images, label = train_dataset[i]
plot_sample_all(images, label, j)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/965774238.py in <module>
#       1 i = 0
#       2 j = 3
# ----> 3 images, label = train_dataset[i]
#       4 plot_sample_all(images, label, j)
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/3171474813.py in __getitem__(self, ids)
#      23
#      24         if split == 'train':
# ---> 25             list_x =  [load_dicom_images_3d_all(x, split) for x in batch_paths]
#      26             batch_X = np.stack(list_x, axis=4)
#      27         else:
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/3171474813.py in <listcomp>(.0)
#      23
#      24         if split == 'train':
# ---> 25             list_x =  [load_dicom_images_3d_all(x, split) for x in batch_paths]
#      26             batch_X = np.stack(list_x, axis=4)
#      27         else:
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/209876507.py in load_dicom_images_3d_all(scan_id, split)
#      55
#      56 def load_dicom_images_3d_all(scan_id, split = 'train'):
# ---> 57     img3d_all = np.concatenate([load_dicom_images_3d(scan_id, split, mri_type) for mri_type in mri_types], axis = -1)
#      58
#      59     return img3d_all
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/209876507.py in <listcomp>(.0)
#      55
#      56 def load_dicom_images_3d_all(scan_id, split = 'train'):
# ---> 57     img3d_all = np.concatenate([load_dicom_images_3d(scan_id, split, mri_type) for mri_type in mri_types], axis = -1)
#      58
#      59     return img3d_all
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/209876507.py in load_dicom_images_3d(scan_id, split, mri_type, num_imgs, img_size, rotate)
#      30     p1 = max(0, middle - num_imgs2)
#      31     p2 = min(len(files), middle + num_imgs2)
# ---> 32     img3d = np.stack([load_dicom_image(f, rotate=rotate) for f in files[p1:p2]]).T
#      33
#      34     # if img3d.shape[-1] < 3*num_imgs//4:
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/209876507.py in <listcomp>(.0)
#      30     p1 = max(0, middle - num_imgs2)
#      31     p2 = min(len(files), middle + num_imgs2)
# ---> 32     img3d = np.stack([load_dicom_image(f, rotate=rotate) for f in files[p1:p2]]).T
#      33
#      34     # if img3d.shape[-1] < 3*num_imgs//4:
#
# C:\Users\SOCHE~1.LAP\AppData\Local\Temp/ipykernel_25788/209876507.py in load_dicom_image(path, img_size, voi_lut, rotate)
#       3     data = dicom.pixel_array
#       4     if voi_lut:
# ----> 5         data = apply_voi_lut(dicom.pixel_array, dicom)
#       6     else:
#       7         data = dicom.pixel_array
#
# ~\anaconda3\envs\kaggle\lib\site-packages\pydicom\pixel_data_handlers\util.py in apply_voi_lut(arr, ds, index, prefer_lut)
#     364
#     365     if valid_windowing:
# --> 366         return apply_windowing(arr, ds, index)
#     367
#     368     return arr
#
# ~\anaconda3\envs\kaggle\lib\site-packages\pydicom\pixel_data_handlers\util.py in apply_windowing(arr, ds, index)
#     581         if between.any():
#     582             arr[between] = (
# --> 583                 ((arr[between] - center) / width + 0.5) * y_range + y_min
#     584             )
#     585     elif voi_func == 'SIGMOID':
#
# KeyboardInterrupt:

# %%
def plot_sample_train(images, label): 
    plt.figure(figsize=(16, 16))
    idx_base = int(NUM_IMAGES_PER_TYPE/2)
    # idx = [idx_base, idx_base*3, idx_base*5, idx_base*7]
    # idx = [idx_base, idx_base*3, idx_base*5]
    # idx = [idx_base, idx_base*3]
    idx = [idx_base]
    for i in range(len(idx)*BATCH_SIZE):
        plt.subplot(BATCH_SIZE,len(idx),i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        j = int(i/len(idx))
        plt.imshow(images[0,:,:,idx[i%len(idx)],j], cmap="gray")
        plt.xlabel(f'{idx[i%len(idx)]} {label[j]}')
    plt.show()

# %%
i = 0
images, label = train_dataset[i]
print("Dimension of the CT scan is:", images.shape)
print("label=",label ,label.shape)
plot_sample_train(images, label)
# Out:
# Dimension of the CT scan is: (1, 128, 128, 64, 4)
# label= [0 0 1 1] (4,)

# %%
def plot_sample_test(images): 
    plt.figure(figsize=(16, 16))
    idx_base = int(NUM_IMAGES_PER_TYPE/2)
    # idx = [idx_base, idx_base*3, idx_base*5, idx_base*7]
    # idx = [idx_base, idx_base*3, idx_base*5]
    # idx = [idx_base, idx_base*3]
    idx = [idx_base]
    for i in range(len(idx)):
        plt.subplot(BATCH_SIZE,len(idx),i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[0,:,:,idx[i]], cmap="gray")
        plt.xlabel(idx[i])
    plt.show()

# %%
i = 0
images = test_dataset[i]
# print(test_dataset[0])
print("Dimension of the CT scan is:", images.shape)
plot_sample_test(images)
# Out:
# Dimension of the CT scan is: (1, 128, 128, 64)

# %% [markdown]
# # Model

# %%
def get_model(width=IMAGE_SIZE, height=IMAGE_SIZE, depth=NUM_IMAGES):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu")(inputs)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.Dropout(0.2)(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.Dropout(0.2)(x)
    
    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.MaxPool3D(pool_size=4)(x)
    x = layers.Dropout(0.2)(x)
    
    # x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    # x = layers.BatchNormalization()(x)

    # x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    # x = layers.BatchNormalization()(x)
    
    # x = layers.MaxPool3D(pool_size=2)(x)
    # x = layers.Dropout(0.2)(x)

    x = layers.Flatten()(x)

    x = layers.Dense(units=128, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3D_CNN")

    return model

# %%
# Build model.
model = get_model()
model.summary()
# Out:
# Model: "3D_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 64, 1)] 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 126, 126, 62, 32)  896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 62, 32)  128
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 124, 124, 60, 32)  27680
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 124, 124, 60, 32)  128
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 62, 62, 30, 32)    0
# _________________________________________________________________
# dropout (Dropout)            (None, 62, 62, 30, 32)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 60, 60, 28, 64)    55360
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60, 60, 28, 64)    256
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 58, 58, 26, 64)    110656
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 58, 58, 26, 64)    256
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 29, 29, 13, 64)    0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29, 29, 13, 64)    0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 27, 27, 11, 128)   221312
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 27, 27, 11, 128)   512
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 25, 25, 9, 128)    442496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 25, 25, 9, 128)    512
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 6, 6, 2, 128)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 2, 128)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,040,097
# Trainable params: 2,039,201
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
print(tf.__version__)
train_dataset[0][0].shape
# Out:
# 2.4.0
# (1, 128, 128, 64, 4)

# %%
from tensorflow.keras.optimizers import schedules, Adam

# Compile model.
initial_learning_rate = 0.0001
lr_schedule = schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=Adam(learning_rate=lr_schedule),
    # metrics=[ AUC(name='auc'), "acc"],
    metrics=["acc"],
)
# Define callbacks.
model_save = ModelCheckpoint('Brain_Tumor_All_MRI_3D_CNN.h5', 
                             save_best_only = True, 
                             monitor = 'val_acc', 
                             mode = 'max', verbose = 1)

early_stop = EarlyStopping(monitor = 'val_acc', 
                           patience = 20, mode = 'max', verbose = 1,
                           restore_best_weights = True)

# Train the model, doing validation at the end of each epoch
epochs = 100


model.fit(
    train_dataset,
    validation_data= valid_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=1,
    callbacks = [model_save, early_stop],
)
# Out:
# Epoch 1/100
# 117/117 [==============================] - 155s 1s/step - loss: 2.5950 - acc: 0.5161 - val_loss: 0.7839 - val_acc: 0.5299
#
# Epoch 00001: val_acc improved from -inf to 0.52991, saving model to Brain_Tumor_All_MRI_3D_CNN.h5
# Epoch 2/100
# 117/117 [==============================] - 146s 1s/step - loss: 1.3529 - acc: 0.5273 - val_loss: 0.7722 - val_acc: 0.5299
#
# Epoch 00002: val_acc did not improve from 0.52991
# Epoch 3/100
# 117/117 [==============================] - 138s 1s/step - loss: 0.7308 - acc: 0.5036 - val_loss: 0.8939 - val_acc: 0.5299
#
# Epoch 00003: val_acc did not improve from 0.52991
# Epoch 4/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.7969 - acc: 0.4749 - val_loss: 0.7766 - val_acc: 0.5299
#
# Epoch 00004: val_acc did not improve from 0.52991
# Epoch 5/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6860 - acc: 0.5593 - val_loss: 0.7162 - val_acc: 0.5299
#
# Epoch 00005: val_acc did not improve from 0.52991
# Epoch 6/100
# 117/117 [==============================] - 134s 1s/step - loss: 0.7008 - acc: 0.4773 - val_loss: 0.7031 - val_acc: 0.5128
#
# Epoch 00006: val_acc did not improve from 0.52991
# Epoch 7/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6862 - acc: 0.5297 - val_loss: 0.6965 - val_acc: 0.5128
#
# Epoch 00007: val_acc did not improve from 0.52991
# Epoch 8/100
# 117/117 [==============================] - 134s 1s/step - loss: 0.6809 - acc: 0.5509 - val_loss: 0.6957 - val_acc: 0.5128
#
# Epoch 00008: val_acc did not improve from 0.52991
# Epoch 9/100
# 117/117 [==============================] - 134s 1s/step - loss: 0.6675 - acc: 0.5788 - val_loss: 0.6985 - val_acc: 0.4615
#
# Epoch 00009: val_acc did not improve from 0.52991
# Epoch 10/100
# 117/117 [==============================] - 134s 1s/step - loss: 0.6663 - acc: 0.5824 - val_loss: 0.7142 - val_acc: 0.4786
#
# Epoch 00010: val_acc did not improve from 0.52991
# Epoch 11/100
# 117/117 [==============================] - 134s 1s/step - loss: 0.6867 - acc: 0.5898 - val_loss: 0.7013 - val_acc: 0.4957
#
# Epoch 00011: val_acc did not improve from 0.52991
# Epoch 12/100
# 117/117 [==============================] - 137s 1s/step - loss: 0.6339 - acc: 0.6259 - val_loss: 0.7028 - val_acc: 0.4786
#
# Epoch 00012: val_acc did not improve from 0.52991
# Epoch 13/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6773 - acc: 0.5900 - val_loss: 0.7124 - val_acc: 0.4957
#
# Epoch 00013: val_acc did not improve from 0.52991
# Epoch 14/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6639 - acc: 0.6220 - val_loss: 0.7144 - val_acc: 0.5128
#
# Epoch 00014: val_acc did not improve from 0.52991
# Epoch 15/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6635 - acc: 0.5886 - val_loss: 0.7193 - val_acc: 0.4786
#
# Epoch 00015: val_acc did not improve from 0.52991
# Epoch 16/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6476 - acc: 0.6076 - val_loss: 0.7005 - val_acc: 0.5128
#
# Epoch 00016: val_acc did not improve from 0.52991
# Epoch 17/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6318 - acc: 0.6412 - val_loss: 0.6928 - val_acc: 0.5128
#
# Epoch 00017: val_acc did not improve from 0.52991
# Epoch 18/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6399 - acc: 0.6214 - val_loss: 0.7137 - val_acc: 0.5128
#
# Epoch 00018: val_acc did not improve from 0.52991
# Epoch 19/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6199 - acc: 0.6634 - val_loss: 0.6957 - val_acc: 0.5299
#
# Epoch 00019: val_acc did not improve from 0.52991
# Epoch 20/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6240 - acc: 0.6506 - val_loss: 0.7152 - val_acc: 0.5641
#
# Epoch 00020: val_acc improved from 0.52991 to 0.56410, saving model to Brain_Tumor_All_MRI_3D_CNN.h5
# Epoch 21/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6330 - acc: 0.6078 - val_loss: 0.7311 - val_acc: 0.4957
#
# Epoch 00021: val_acc did not improve from 0.56410
# Epoch 22/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6048 - acc: 0.6640 - val_loss: 0.7043 - val_acc: 0.5470
#
# Epoch 00022: val_acc did not improve from 0.56410
# Epoch 23/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6087 - acc: 0.6655 - val_loss: 0.7217 - val_acc: 0.5299
#
# Epoch 00023: val_acc did not improve from 0.56410
# Epoch 24/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6329 - acc: 0.6554 - val_loss: 0.7217 - val_acc: 0.4957
#
# Epoch 00024: val_acc did not improve from 0.56410
# Epoch 25/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6105 - acc: 0.6597 - val_loss: 0.7222 - val_acc: 0.4957
#
# Epoch 00025: val_acc did not improve from 0.56410
# Epoch 26/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6098 - acc: 0.6662 - val_loss: 0.7347 - val_acc: 0.5470
#
# Epoch 00026: val_acc did not improve from 0.56410
# Epoch 27/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6048 - acc: 0.6402 - val_loss: 0.7055 - val_acc: 0.5299
#
# Epoch 00027: val_acc did not improve from 0.56410
# Epoch 28/100
# 117/117 [==============================] - 137s 1s/step - loss: 0.6105 - acc: 0.6515 - val_loss: 0.7249 - val_acc: 0.4957
#
# Epoch 00028: val_acc did not improve from 0.56410
# Epoch 29/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.5902 - acc: 0.6750 - val_loss: 0.7506 - val_acc: 0.5299
#
# Epoch 00029: val_acc did not improve from 0.56410
# Epoch 30/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6036 - acc: 0.6735 - val_loss: 0.7524 - val_acc: 0.4957
#
# Epoch 00030: val_acc did not improve from 0.56410
# Epoch 31/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.5992 - acc: 0.6432 - val_loss: 0.7487 - val_acc: 0.4274
#
# Epoch 00031: val_acc did not improve from 0.56410
# Epoch 32/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.5670 - acc: 0.6906 - val_loss: 0.7292 - val_acc: 0.5299
#
# Epoch 00032: val_acc did not improve from 0.56410
# Epoch 33/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.6429 - acc: 0.6230 - val_loss: 0.8049 - val_acc: 0.4444
#
# Epoch 00033: val_acc did not improve from 0.56410
# Epoch 34/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.5996 - acc: 0.6402 - val_loss: 0.7271 - val_acc: 0.5299
#
# Epoch 00034: val_acc did not improve from 0.56410
# Epoch 35/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.6028 - acc: 0.6518 - val_loss: 0.7531 - val_acc: 0.4957
#
# Epoch 00035: val_acc did not improve from 0.56410
# Epoch 36/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.5889 - acc: 0.6640 - val_loss: 0.7641 - val_acc: 0.4957
#
# Epoch 00036: val_acc did not improve from 0.56410
# Epoch 37/100
# 117/117 [==============================] - 137s 1s/step - loss: 0.5893 - acc: 0.6657 - val_loss: 0.7393 - val_acc: 0.5470
#
# Epoch 00037: val_acc did not improve from 0.56410
# Epoch 38/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.5580 - acc: 0.6783 - val_loss: 0.8070 - val_acc: 0.4786
#
# Epoch 00038: val_acc did not improve from 0.56410
# Epoch 39/100
# 117/117 [==============================] - 136s 1s/step - loss: 0.5784 - acc: 0.6773 - val_loss: 0.7115 - val_acc: 0.5299
#
# Epoch 00039: val_acc did not improve from 0.56410
# Epoch 40/100
# 117/117 [==============================] - 135s 1s/step - loss: 0.5900 - acc: 0.6748 - val_loss: 0.7773 - val_acc: 0.5128
#
# Epoch 00040: val_acc did not improve from 0.56410
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping

# %% [markdown]
# # Visualizing model performance

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
del train_dataset
del valid_dataset

# %%
model.load_weights('./Brain_Tumor_All_MRI_3D_CNN.h5')

# %%
from tensorflow.keras.utils import Sequence

class Dataset(Sequence):
    def __init__(self,df,is_train=True,batch_size=1,shuffle=True):
        self.idx = df["BraTS21ID"].values
        self.paths = df["BraTS21ID5"].values
        self.y =  df["MGMT_value"].values
        self.is_train = is_train
        self.batch_size = batch_size
        self.shuffle = shuffle
    def __len__(self):
        return math.ceil(len(self.idx)/self.batch_size)
   
    def __getitem__(self,ids):
        id_path= self.paths[ids]
        batch_paths = self.paths[ids * self.batch_size:(ids + 1) * self.batch_size]
        
        if self.y is not None:
            batch_y = self.y[ids * self.batch_size: (ids + 1) * self.batch_size]
            
        list_x =  load_dicom_images_3d_all(id_path, 'test') #str(scan_id).zfill(5)
        #list_x =  [load_dicom_images_3d(x) for x in batch_paths]
        batch_X = np.stack(list_x)
        if self.is_train:
            return batch_X,batch_y
        else:
            return batch_X
    
    def on_epoch_end(self):
        if self.shuffle and self.is_train:
            ids_y = list(zip(self.idx, self.y))
            shuffle(ids_y)
            self.idx, self.y = list(zip(*ids_y))

# %%
test_dataset = Dataset(df=test, is_train=False)

# %%
preds = model.predict(test_dataset)

# %%
preds = preds.reshape(-1)

# %%
submission = pd.DataFrame({'BraTS21ID':sample_submission['BraTS21ID'],'MGMT_value':preds})

# %%
submission
# Out:
#     BraTS21ID  MGMT_value
# 0           1    0.532825
# 1          13    0.530010
# 2          15    0.529985
# 3          27    0.528844
# 4          37    0.528155
# ..        ...         ...
# 82        826    0.514171
# 83        829    0.527880
# 84        833    0.532999
# 85        997    0.532425
# 86       1006    0.527515
#
# [87 rows x 2 columns]

# %%
submission['BraTS21ID'] = [format(x, '05d') for x in submission.BraTS21ID]

# %%
submission
# Out:
#    BraTS21ID  MGMT_value
# 0      00001    0.532825
# 1      00013    0.530010
# 2      00015    0.529985
# 3      00027    0.528844
# 4      00037    0.528155
# ..       ...         ...
# 82     00826    0.514171
# 83     00829    0.527880
# 84     00833    0.532999
# 85     00997    0.532425
# 86     01006    0.527515
#
# [87 rows x 2 columns]

# %%
submission.to_csv('submission.csv',index=False)
